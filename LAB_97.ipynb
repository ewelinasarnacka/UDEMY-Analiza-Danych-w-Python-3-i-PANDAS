# %% [markdown]
# # LAB 97
#
# 1. Zaimportuj moduł pandas i numpy, nadaj im standardowe aliasy. Do zmiennej air wczytaj zawartość pliku Air_Traffic_Passenger_Statistics.csv. Pobierz wszystkie kolumny. Zdefiniuj multiindex w oparciu o kolumny "Operating Airline","Activity Period","Activity Type Code", posortuj dane wg indeksu i wświetl nagłówek obiektu data frame.
# 2. Wyświetl informacje o lotach obsługiwanych przez Air France, w lipcu 2005 roku z zawężeniem danych dolądowania (klucz będzie zawierał dane: 'Air France',200507,'Enplaned')
# 3. Wyświetl informacje o lotach obsługiwanych przez Air France, w lipcu 2005 roku (klucz będzie zawierał dane: 'Air France',200507)
# 4. Wyświetl informacje o lotach obsługiwanych przez Air France (klucz będzie zawierał dane: 'Air France'). Ponieważ zbiór jest duży, wyświetl tylko początkowe wiersze.
# 5. Wyświetl informacje z kolumny 'Passenger Count dla klucza 'Air France',200507,'Enplaned'
# 6. Wyświetl informacje z kolumny 'Passenger Count dla klucza 'Air France',200507,'Deplaned'
# 7. Wyświetl wiersze od 20 do 25
# 8. Dla wierszy od 20 do 25 wyświetl informacje z kolumny 8

# %% [markdown]
# ## Exercise 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math

# %%
air = pd.read_csv("./Air_Traffic_Passenger_Statistics.csv")
air.set_index(["Operating Airline","Activity Period","Activity Type Code"],inplace=True)
air.sort_index(inplace=True)
air.head(10)
# Out:
#                                                                             Operating Airline IATA Code  \
# Operating Airline                        Activity Period Activity Type Code
# ABC Aerolineas S.A. de C.V. dba Interjet 201803          Deplaned                                    4O
#                                                          Enplaned                                    4O
# ATA Airlines                             200507          Deplaned                                    TZ
#                                                          Enplaned                                    TZ
#                                                          Thru / Transit                              TZ
#                                          200508          Deplaned                                    TZ
#                                                          Enplaned                                    TZ
# ...

# %% [markdown]
# ## Exercise 2

# %%
air.loc[('Air France',200507,'Enplaned')]
# Out:
#                                                      Operating Airline IATA Code  \
# Operating Airline Activity Period Activity Type Code
# Air France        200507          Enplaned                                    AF
#
#                                                      Published Airline  \
# Operating Airline Activity Period Activity Type Code
# Air France        200507          Enplaned                  Air France
#
#                                                      Published Airline IATA Code  \
# Operating Airline Activity Period Activity Type Code
# Air France        200507          Enplaned                                    AF
#
#                                                         GEO Summary  \
# Operating Airline Activity Period Activity Type Code
# Air France        200507          Enplaned            International
#
#                                                      GEO Region  \
# Operating Airline Activity Period Activity Type Code
# ...

# %%
#air.sort_values("Operating Airline", inplace=True)
filter1 = air["Operating Airline"]=="Air France"
#air_sort.where(filter)
#type(air)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Operating Airline'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-e57372eb8cf0> in <module>
# ...

# %% [markdown]
# ## Exercise 3

# %%
air.loc[('Air France',200507)]
# Out:
#                    Operating Airline IATA Code Published Airline  \
# Activity Type Code
# Deplaned                                    AF        Air France
# Enplaned                                    AF        Air France
#
#                    Published Airline IATA Code    GEO Summary GEO Region  \
# Activity Type Code
# Deplaned                                    AF  International     Europe
# Enplaned                                    AF  International     Europe
#
#                    Price Category Code       Terminal Boarding Area  \
# Activity Type Code
# Deplaned                         Other  International             A
# Enplaned                         Other  International             A
#
#                     Passenger Count
# Activity Type Code
# Deplaned                      12050
# Enplaned                      11638

# %% [markdown]
# ## Exercise 4

# %%
air.loc[('Air France')].head()
# Out:
#                                    Operating Airline IATA Code  \
# Activity Period Activity Type Code
# 200507          Deplaned                                    AF
#                 Enplaned                                    AF
# 200508          Deplaned                                    AF
#                 Enplaned                                    AF
# 200509          Deplaned                                    AF
#
#                                    Published Airline  \
# Activity Period Activity Type Code
# 200507          Deplaned                  Air France
#                 Enplaned                  Air France
# 200508          Deplaned                  Air France
#                 Enplaned                  Air France
# 200509          Deplaned                  Air France
#
#                                    Published Airline IATA Code    GEO Summary  \
# Activity Period Activity Type Code
# ...

# %% [markdown]
# ## Exercise 5

# %%
air.loc[('Air France',200507,'Enplaned'),'Passenger Count']
# Out:
# Operating Airline  Activity Period  Activity Type Code
# Air France         200507           Enplaned              11638
# Name: Passenger Count, dtype: int64

# %% [markdown]
# ## Exercise 6

# %%
air.loc[('Air France',200507,'Deplaned'),'Passenger Count']
# Out:
# Operating Airline  Activity Period  Activity Type Code
# Air France         200507           Deplaned              12050
# Name: Passenger Count, dtype: int64

# %% [markdown]
# ## Exercise 7

# %%
air.iloc[20:25]
# Out:
#                                                      Operating Airline IATA Code  \
# Operating Airline Activity Period Activity Type Code
# ATA Airlines      200512          Enplaned                                    TZ
#                                   Thru / Transit                              TZ
#                   200601          Deplaned                                    TZ
#                                   Enplaned                                    TZ
#                                   Thru / Transit                              TZ
#
#                                                      Published Airline  \
# Operating Airline Activity Period Activity Type Code
# ATA Airlines      200512          Enplaned                ATA Airlines
#                                   Thru / Transit          ATA Airlines
#                   200601          Deplaned                ATA Airlines
#                                   Enplaned                ATA Airlines
# ...

# %% [markdown]
# ## Exercise 8

# %%
air.iloc[20:25,8]
# Out:
# Operating Airline  Activity Period  Activity Type Code
# ATA Airlines       200512           Enplaned              16790
#                                     Thru / Transit         2402
#                    200601           Deplaned              13010
#                                     Enplaned              12226
#                                     Thru / Transit         3316
# Name: Passenger Count, dtype: int64
