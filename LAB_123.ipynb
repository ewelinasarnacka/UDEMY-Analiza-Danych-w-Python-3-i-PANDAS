# %% [markdown]
# # LAB 123
#
# 1. Zaimportuj moduł pandas i numpy nadaj im standardowe aliasy
# 2. Do zmiennej products zaimportuj zawartość pliku products.csv (znajduje się w podkatalogu northwindmongo-master, jeśli korzystasz z materiałów kursowych)
# 3. Wyświetl informacje o produkcie, którego nazwa (kolumna ProductName) to 'Ravioli Angelo'
# 4. Do zmiennej categories zaimportuj zawartość pliku categories1.csv
# 5. Popatrz na wynik polecenia (3). Znaleziony produkt należy do pewnej kategorii, ale kategoria ta jest oznaczona tylko liczbą. Wyświetl wiersz z categories, który w kolumnie CategoryID ma właśnie tą liczbę
# 6. Do zmiennej suppliers zaimportuj zawartość pliku suppliers.csv
# 7. Popatrz na wynik polecenia (3). Znaleziony produkt jest dostarczany przez pewnego dostawcę ale nie wiemy kim jest ten dostawca, jaki ma nr telefonu itp. Znamy tylko liczbę, która jest identyfikatorem dostawcy w tabeli suppliers. Wyświetl wiersz z suppliers, który w kolumnie SupplierID ma właśnie tą liczbę

# %% [markdown]
# ## Exercsie 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math

# %% [markdown]
# ## Exercsie 2

# %%
products = pd.read_csv('./products.csv')
products.head()
# Out:
#    ProductID                   ProductName  SupplierID  CategoryID  \
# 0          1                          Chai           1           1
# 1          2                         Chang           1           1
# 2          3                 Aniseed Syrup           1           2
# 3          4  Chef Anton's Cajun Seasoning           2           2
# 4          5        Chef Anton's Gumbo Mix           2           2
#
#        QuantityPerUnit  UnitPrice  UnitsInStock  UnitsOnOrder  ReorderLevel  \
# 0   10 boxes x 20 bags      18.00            39             0            10
# 1   24 - 12 oz bottles      19.00            17            40            25
# 2  12 - 550 ml bottles      10.00            13            70            25
# 3       48 - 6 oz jars      22.00            53             0             0
# 4             36 boxes      21.35             0             0             0
#
#    Discontinued
# 0             0
# 1             0
# 2             0
# 3             0
# 4             1

# %% [markdown]
# ## Exercise 3

# %%
products.loc[products['ProductName'] == 'Ravioli Angelo']
# Out:
#     ProductID     ProductName  SupplierID  CategoryID   QuantityPerUnit  \
# 56         57  Ravioli Angelo          26           5  24 - 250 g pkgs.
#
#     UnitPrice  UnitsInStock  UnitsOnOrder  ReorderLevel  Discontinued
# 56       19.5            36             0            20             0

# %% [markdown]
# ## Exercise 4

# %%
categories = pd.read_csv('./categories1.csv')
categories.head()
# Out:
#    CategoryID    CategoryName              Description
# 0           1       Beverages              Soft drinks
# 1           2      Condiments  Sweet and savory sauces
# 2           3     Confections                 Desserts
# 3           4  Dairy Products                  Cheeses
# 4           5  Grains/Cereals                   Breads

# %% [markdown]
# ## Exercsie 5

# %%
categories.loc[categories['CategoryID'] == 5]
# Out:
#    CategoryID    CategoryName Description
# 4           5  Grains/Cereals      Breads

# %% [markdown]
# ## Exercise 6

# %%
suppliers = pd.read_csv('./suppliers.csv')
suppliers.head()
# Out:
#    SupplierID                         CompanyName                 ContactName  \
# 0           1                      Exotic Liquids            Charlotte Cooper
# 1           2          New Orleans Cajun Delights               Shelley Burke
# 2           3           Grandma Kelly's Homestead               Regina Murphy
# 3           4                       Tokyo Traders                Yoshi Nagase
# 4           5  Cooperativa de Quesos 'Las Cabras'  Antonio del Valle Saavedra
#
#            ContactTitle                    Address         City    Region  \
# 0    Purchasing Manager             49 Gilbert St.       London       NaN
# 1   Order Administrator             P.O. Box 78934  New Orleans        LA
# 2  Sales Representative             707 Oxford Rd.    Ann Arbor        MI
# 3     Marketing Manager  9-8 Sekimai Musashino-shi        Tokyo       NaN
# 4  Export Administrator          Calle del Rosal 4       Oviedo  Asturias
#
#   PostalCode Country           Phone             Fax     HomePage
# 0    EC1 4SD      UK  (171) 555-2222             NaN          NaN
# 1      70117     USA  (100) 555-4822             NaN  #CAJUN.HTM#
# 2      48104     USA  (313) 555-5735  (313) 555-3349          NaN
# 3        100   Japan  (03) 3555-5011             NaN          NaN
# 4      33007   Spain  (98) 598 76 54             NaN          NaN

# %% [markdown]
# ## Exercise 7

# %%
suppliers.loc[suppliers['SupplierID'] == 26]
# Out:
#     SupplierID           CompanyName       ContactName         ContactTitle  \
# 25          26  Pasta Buttini s.r.l.  Giovanni Giudici  Order Administrator
#
#                   Address     City Region PostalCode Country          Phone  \
# 25  Via dei Gelsomini 153  Salerno    NaN      84100   Italy  (089) 6547665
#
#               Fax HomePage
# 25  (089) 6547667      NaN
